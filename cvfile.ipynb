# %%
"""
        if 'CV' in experiment_type:
            preprocessing.pull_cv_metadata()
            curve_data = preprocessing.extract_cv_curves()
            surface_area = self.surface_area_input.get()
            extras = preprocessing.get_extra_data()
            analysis = Analysis(curve_data, preprocessing.sampling_rate, surface_area, extras)
            results = analysis.process_curves()
            visualization.open_save_dialog()
            save_path = visualization.get_save_path()
            name = filepath.split('/')[-1]
            visualization.output_as_csv(results, preprocessing.vlimit1, preprocessing.vlimit2, name)
"""
# Out:
# "\n        if 'CV' in experiment_type:\n            preprocessing.pull_cv_metadata()\n            curve_data = preprocessing.extract_cv_curves()\n            surface_area = self.surface_area_input.get()\n            extras = preprocessing.get_extra_data()\n            analysis = Analysis(curve_data, preprocessing.sampling_rate, surface_area, extras)\n            results = analysis.process_curves()\n            visualization.open_save_dialog()\n            save_path = visualization.get_save_path()\n            name = filepath.split('/')[-1]\n            visualization.output_as_csv(results, preprocessing.vlimit1, preprocessing.vlimit2, name)\n"

# %% [markdown]
# ### Adding Selective Curve Functionality

# %%
from preprocessing import Preprocessor
from analysis import Analysis
import pandas as pd
import matplotlib.pyplot as plt

# %%
filepath = '/Users/maxtenenbaum/Desktop/20240717_IF0003_IIA31_C_PEDOT_E01_CV50.DTA'
preprocessing = Preprocessor(filepath)

# %%
preprocessing.pull_cv_metadata()

# %%
curve_data = preprocessing.extract_cv_curves()
print(curve_data)
# Out:
# {'CURVE1':      V vs. Ref.             A
# 0      0.203314 -2.277980e-09
# 1      0.213291  2.229470e-08
# 2      0.223289  2.733520e-08
# 3      0.233280  2.967940e-08
# 4      0.243289  3.089440e-08
# ..          ...           ...
# 186   -0.856664 -7.544270e-08
# 187   -0.866665 -7.050660e-08
# 188   -0.876663 -6.560580e-08
# 189   -0.886651 -6.075470e-08
# 190   -0.896670 -5.625140e-08
#
# [191 rows x 2 columns], 'CURVE2':         V vs. Ref.              A
# 0               Vf             Im
# 1    -8.89965E-001  -3.88658E-008
# 2    -8.79974E-001  -2.85952E-008
# 3    -8.69971E-001  -2.18958E-008
# 4    -8.60004E-001  -1.63847E-008
# ..             ...            ...
# 296  -8.59981E-001  -6.19337E-008
# 297  -8.69949E-001  -5.84822E-008
# 298  -8.79944E-001  -5.49110E-008
# 299  -8.89950E-001  -5.14018E-008
# 300  -8.99994E-001  -4.79711E-008
#
# [301 rows x 2 columns], 'CURVE3':         V vs. Ref.              A
# 0               Vf             Im
# 1    -8.89960E-001  -2.89597E-008
# 2    -8.79967E-001  -2.08621E-008
# 3    -8.69970E-001  -1.48049E-008
# 4    -8.60009E-001  -9.77078E-009
# ..             ...            ...
# 296  -8.59973E-001  -5.89791E-008
# 297  -8.69947E-001  -5.57252E-008
# 298  -8.79953E-001  -5.24333E-008
# 299  -8.89942E-001  -4.92017E-008
# 300  -8.99976E-001  -4.59635E-008
#
# [301 rows x 2 columns], 'CURVE4':         V vs. Ref.              A
# 0               Vf             Im
# 1    -8.89954E-001  -2.69172E-008
# 2    -8.79968E-001  -1.87742E-008
# 3    -8.69969E-001  -1.27923E-008
# 4    -8.60004E-001  -7.80249E-009
# ..             ...            ...
# 106   1.59976E-001   6.05816E-008
# 107   1.69972E-001   6.08004E-008
# 108   1.79973E-001   6.09735E-008
# 109   1.89952E-001   6.11417E-008
# 110   1.99991E-001   6.15014E-008
#
# [111 rows x 2 columns]}

# %%
surface_area = 0.0000199504
extras = preprocessing.get_extra_data()
analysis = Analysis(curve_data, preprocessing.sampling_rate, surface_area)

# %%
results = analysis.process_curves()

# %%
print(results)
# Out:
#   Curve #   CSC_A   CSC_C  Total_Anodal_Charge  Total_Cathodal_Charge      Qh
# 0  CURVE1  14.615  91.284              291.567               1821.154  52.949
# 1  CURVE2  71.734  85.240             1431.128               1700.579  78.487
# 2  CURVE3  71.563  82.634             1427.702               1648.577  77.098
# 3  CURVE4  43.772   0.560              873.272                 11.181  22.166

# %%
selected_curves = ['CURVE1', 'CURVE2', 'CURVE3', 'CURVE4']
selected_indices = [i for i in range(len(selected_curves))]
print(selected_curves)
print(selected_indices)
# Out:
# ['CURVE1', 'CURVE2', 'CURVE3', 'CURVE4']
# [0, 1, 2, 3]

# %%
selected_curves = ['CURVE1', 'CURVE3']

for curve in results['Curve #']:
    if curve not in selected_curves:
        results.drop(index=results.loc[results['Curve #'] == curve].index[0], inplace=True)

# %%
print(results)
# Out:
#   Curve #   CSC_A   CSC_C  Total_Anodal_Charge  Total_Cathodal_Charge      Qh
# 0  CURVE1  14.615  91.284              291.567               1821.154  52.949
# 2  CURVE3  71.563  82.634             1427.702               1648.577  77.098

# %%
selected_curves = ['CURVE1', 'CURVE3']
drop_rows = []

for curve in results['Curve #']:
    if curve not in selected_curves:
        drop_rows.append(results.loc[results['Curve #'] == curve].index[0])

print(drop_rows)
# Out:
# []

# %%
for row in drop_rows:
    results.drop(index=row, inplace=True)

# %%
print(results)
# Out:
#   Curve #   CSC_A   CSC_C  Total_Anodal_Charge  Total_Cathodal_Charge      Qh
# 0  CURVE1  14.615  91.284              291.567               1821.154  52.949
# 2  CURVE3  71.563  82.634             1427.702               1648.577  77.098

# %% [markdown]
# ### Adding Extra Data

# %%
full_df = preprocessing.extract_cv_curves(get_curves=True)
print(full_df)
# Out:
#          s     V vs. Ref.              A             V              V  \
# 0        T             Vf             Im            Vu            Sig
# 1    158.4  -8.89954E-001  -2.69172E-008  0.00000E+000  -8.89977E-001
# 2    158.6  -8.79968E-001  -1.87742E-008  0.00000E+000  -8.79983E-001
# 3    158.8  -8.69969E-001  -1.27923E-008  0.00000E+000  -8.69990E-001
# 4      159  -8.60004E-001  -7.80249E-009  0.00000E+000  -8.59997E-001
# ..     ...            ...            ...           ...            ...
# 106  179.4   1.59976E-001   6.05816E-008  0.00000E+000   1.59996E-001
# 107  179.6   1.69972E-001   6.08004E-008  0.00000E+000   1.69989E-001
# 108  179.8   1.79973E-001   6.09735E-008  0.00000E+000   1.79982E-001
# 109    180   1.89952E-001   6.11417E-008  0.00000E+000   1.89975E-001
# 110  180.2   1.99991E-001   6.15014E-008  0.00000E+000   2.00018E-001
#
#                 V        #         bits    deg C
# 0             Ach  IERange         Over     Temp
# 1    0.00000E+000        7  ...........  1399.34
# 2    0.00000E+000        7  ...........  1399.34
# 3    0.00000E+000        7  ...........  1399.34
# 4    0.00000E+000        7  ...........  1399.34
# ..            ...      ...          ...      ...
# 106  0.00000E+000        7  ...........  1399.25
# 107  0.00000E+000        7  ...........  1399.25
# 108  0.00000E+000        7  ...........  1399.25
# 109  0.00000E+000        7  ...........  1399.25
# 110  0.00000E+000        7  ...........  1399.25
#
# [111 rows x 9 columns]

# %%
print(full_df[['V vs. Ref.','A']])
# Out:
#         V vs. Ref.              A
# 0               Vf             Im
# 1    -8.89954E-001  -2.69172E-008
# 2    -8.79968E-001  -1.87742E-008
# 3    -8.69969E-001  -1.27923E-008
# 4    -8.60004E-001  -7.80249E-009
# ..             ...            ...
# 106   1.59976E-001   6.05816E-008
# 107   1.69972E-001   6.08004E-008
# 108   1.79973E-001   6.09735E-008
# 109   1.89952E-001   6.11417E-008
# 110   1.99991E-001   6.15014E-008
#
# [111 rows x 2 columns]

# %%
extra_df = full_df[['V vs. Ref.','A']]

# %%
extra_df = extra_df.drop(extra_df.index[0]).reset_index(drop=True)

# %%
print(extra_df)
# Out:
#         V vs. Ref.              A
# 0    -8.89954E-001  -2.69172E-008
# 1    -8.79968E-001  -1.87742E-008
# 2    -8.69969E-001  -1.27923E-008
# 3    -8.60004E-001  -7.80249E-009
# 4    -8.49993E-001  -3.36091E-009
# ..             ...            ...
# 105   1.59976E-001   6.05816E-008
# 106   1.69972E-001   6.08004E-008
# 107   1.79973E-001   6.09735E-008
# 108   1.89952E-001   6.11417E-008
# 109   1.99991E-001   6.15014E-008
#
# [110 rows x 2 columns]

# %%
results = pd.concat([results, extra_df[['V vs. Ref.','A']]], axis=1)

# %%
print(results['V vs. Ref.'])
# Out:
# 0      -8.89954E-001
# 2      -8.69969E-001
# 1      -8.79968E-001
# 3      -8.60004E-001
# 4      -8.49993E-001
#            ...
# 105     1.59976E-001
# 106     1.69972E-001
# 107     1.79973E-001
# 108     1.89952E-001
# 109     1.99991E-001
# Name: V vs. Ref., Length: 110, dtype: object

# %%
print(results['V vs. Ref.'].dtype)
# Out:
# object

# %%
#results['V vs. Ref.'] = pd.to_numeric(results['V vs. Ref.'], errors='coerce')
#results['A'] = pd.to_numeric(results['A'], errors='coerce')

# %%
plt.plot(results['V vs. Ref.'], results['A'], marker='o', markersize=4, alpha = 0.7)

# %%
print(results['V vs. Ref.'].dtype)
# Out:
# object

# %%
print(results['CSC_C'].dtype)
# Out:
# float64

# %%
x = results['A']

# %%
print(x.dtype)
# Out:
# object

# %%
x = pd.to_numeric(x)

# %%
print(x.dtype)
# Out:
# float64
